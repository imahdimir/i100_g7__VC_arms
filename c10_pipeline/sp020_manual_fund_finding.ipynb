# %%
import sys
import pandas as pd

sys.modules.pop('a20_config.a10_config', None)  # force reload
from a20_config.a10_config import dyr, file, var

# %%
# !cd "/sharedata/camm/data/i83_g7__VC_arms_data/inp"

# %%
# # cd = proj_data/inp/
# !unzip Pitchbook-Full-Data.zip -d ./Pitchbook_full_data
# !rm Pitchbook-Full-Data.zip

# %%
df_funds = pd.read_parquet(file.pb_fund__parq)
print(df_funds.shape)
df_funds
# Out:
# (93355, 43)
#           FundID                                    FundName FundFormerName  \
# 0      10909-00F             Charterhouse Equity Partners IV           None
# 1      21394-63F                    Circular Innovation Fund           None
# 2      10909-27F                         Brynwood Partners V           None
# 3      21394-99F                        Sirios Overseas Fund           None
# 4      10909-36F         Cerberus Institutional Partners III           None
# ...          ...                                         ...            ...
# 93350  23055-22F                BrandProject Capital Fund II           None
# 93351  23354-47F  Oak Street Investment Grade Net Lease Fund           None
# 93352  23278-87F     Hillhouse Real Asset Opportunities Fund           None
# 93353  23168-53F             Aultmore Capital Cre Property I           None
# 93354  23400-28F                         Kkr Credit Partners           None
#
# ...

# %%
inv_1 = ['Ascension Ventures']
msk = df_funds[var.investor].eq(inv_1[0])
df_1 = df_funds[msk]

# next two lines: to see all the columns and values for the filtered data 
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# sort funds based on the FundNo for a nicer view of the data
df_1 = df_1.sort_values(var.fund_no)
df_1
# Out:
#           FundID                         FundName FundFormerName FundNo  \
# 1422   11004-85F        Ascension Health Ventures           None      1
# 87846  11715-58F                           CHV II           None      2
# 62206  13492-36F                          CHV III           None      3
# 59637  15744-88F                           CHV IV           None      4
# 29027  17559-19F  Collaborative Health Ventures V           None      5
#
#                       FirstFund            Investor  \
# 1422   Yes (Ascension Ventures)  Ascension Ventures
# 87846                      None  Ascension Ventures
# 62206                      None  Ascension Ventures
# 59637                      None  Ascension Ventures
# 29027                      None  Ascension Ventures
#
#                                       InvestorWebsite  Vintage FundStatus  \
# 1422   Ascension Ventures (www.ascensionventures.org)   2001.0     Closed
# ...

# %%
# the list of fund Ids for 1
fund_ids_dict = {
        1: list(df_1[var.fund_id]),
}
fund_ids_dict[1]
# Out:
# ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F']

# %%
fund_investors_dict = {
        1: inv_1
}
fund_investors_dict
# Out:
# {1: ['Ascension Ventures']}

# %%
fund_ids_dict[2] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'], 2: []}

# %%
fund_investors_dict[2] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'], 2: []}

# %%
fund_ids_dict[3] = []

# %%
fund_investors_dict[3] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'], 2: [], 3: []}

# %%
fund_ids_dict[4] = []

# %%
fund_investors_dict[4] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'], 2: [], 3: [], 4: []}

# %%
fund_ids_dict[5] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: []}

# %%
fund_investors_dict[5] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'], 2: [], 3: [], 4: [], 5: []}

# %%
inv_6 = ["Intermountain Ventures"]
msk = df_funds[var.investor].eq(inv_6[0])
df_6 = df_funds[msk]
df_6
# Out:
#           FundID                     FundName FundFormerName FundNo  \
# 46027  17580-43F  Intermountain Ventures Fund           None      1
#
#                           FirstFund                Investor  \
# 46027  Yes (Intermountain Ventures)  Intermountain Ventures
#
#                                          InvestorWebsite  Vintage FundStatus  \
# 46027  Intermountain Ventures (intermountainventures....      NaN     Closed
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 46027       NaN             NaN                USD          None
#
#           FundCategory           FundType FundAccessPoint SBICFund CloseDate  \
# 46027  Venture Capital  Venture - General    Primary Fund       No      None
#
#       OpenDate  FundTargetSizeLow  FundTargetSizeHigh FundTargetSize  \
# 46027     None                NaN                 NaN           None
#
#            Domiciles        FundLocation        FundCity FundState_Province  \
# ...

# %%
fund_ids_dict[6] = list(df_6[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F']}

# %%
fund_investors_dict[6] = inv_6
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures']}

# %%
fund_ids_dict[7] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: []}

# %%
fund_investors_dict[7] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: []}

# %%
fund_ids_dict[8] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: []}

# %%
fund_investors_dict[8] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: []}

# %%
inv_9 = ["Kaiser Permanente Ventures"]
msk = df_funds[var.investor].eq(inv_9[0])
df_9 = df_funds[msk]
df_9
# Out:
#           FundID                                FundName FundFormerName  \
# 53466  16929-91F                              KPV Fund V           None
# 68078  13943-26F         Kaiser Permanente Ventures Fund           None
# 75853  13168-45F     Kaiser Permanente Healthcare Fund V           None
# 82308  11195-11F                    KP Healthcare Fund I           None
# 82310  11195-20F                   KP Healthcare Fund II           None
# 82312  11195-29F  Kaiser Permanente Healthcare Side Fund           None
# 82314  11195-38F   Kaiser Permanente Healthcare Fund III           None
# 82316  11195-47F    Kaiser Permanente Healthcare Fund IV           None
#
#       FundNo                         FirstFund                    Investor  \
# 53466      8                              None  Kaiser Permanente Ventures
# 68078      7                              None  Kaiser Permanente Ventures
# 75853      6                              None  Kaiser Permanente Ventures
# ...

# %%
fund_ids_dict[9] = list(df_9[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F']}

# %%
fund_investors_dict[9] = inv_9
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures']}

# %%
inv_10 = ["Ochsner Lafayette General"]
msk = df_funds[var.investor].eq(inv_10[0])
df_10 = df_funds[msk]
df_10
# Out:
#           FundID                    FundName FundFormerName FundNo  \
# 56241  15463-27F  Healthcare Innovation Fund           None      1
#
#                              FirstFund                   Investor  \
# 56241  Yes (Ochsner Lafayette General)  Ochsner Lafayette General
#
#                                      InvestorWebsite  Vintage FundStatus  \
# 56241  Ochsner Lafayette General (www.ochsnerlg.org)      NaN     Closed
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 56241       2.5             2.5                USD       0 - 99M
#
#           FundCategory                       FundType FundAccessPoint  \
# 56241  Venture Capital  Venture Capital - Early Stage    Primary Fund
#
#       SBICFund CloseDate    OpenDate  FundTargetSizeLow  FundTargetSizeHigh  \
# 56241       No      None  01/01/2016                NaN                 NaN
#
#       FundTargetSize      Domiciles   FundLocation   FundCity  \
# ...

# %%
fund_ids_dict[10] = list(df_10[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F']}

# %%
fund_investors_dict[10] = inv_10
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General']}

# %%
inv_11 = ["Mayo Clinic Ventures"]
msk = df_funds[var.investor].eq(inv_11[0])
df_11 = df_funds[msk]
df_11
# Out:
#           FundID                          FundName FundFormerName FundNo  \
# 59038  16885-63F  Mayo Benefactors Innovation Fund           None      1
#
#                         FirstFund              Investor  \
# 59038  Yes (Mayo Clinic Ventures)  Mayo Clinic Ventures
#
#                                       InvestorWebsite  Vintage FundStatus  \
# 59038  Mayo Clinic Ventures (ventures.mayoclinic.org)   2020.0     Closed
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 59038       NaN             NaN                USD          None
#
#           FundCategory           FundType FundAccessPoint SBICFund  \
# 59038  Venture Capital  Venture - General    Primary Fund       No
#
#         CloseDate OpenDate  FundTargetSizeLow  FundTargetSizeHigh  \
# 59038  01/01/2020     None                NaN                 NaN
#
#       FundTargetSize      Domiciles   FundLocation   FundCity  \
# 59038           None  United States  Rochester, MN  Rochester
#
# ...

# %%
fund_ids_dict[11] = list(df_11[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F']}

# %%
fund_investors_dict[11] = inv_11
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures']}

# %%
inv_12 = ["MemorialCare Innovation Fund"]
msk = df_funds[var.investor].eq(inv_12[0])
df_12 = df_funds[msk]
df_12
# Out:
#           FundID                      FundName FundFormerName FundNo  \
# 67050  13847-14F  MemorialCare Innovation Fund           None      1
#
#                                 FirstFund                      Investor  \
# 67050  Yes (MemorialCare Innovation Fund)  MemorialCare Innovation Fund
#
#                                          InvestorWebsite  Vintage FundStatus  \
# 67050  MemorialCare Innovation Fund (www.memorialcare...   2013.0     Closed
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 67050     150.0           150.0                USD   100M - 249M
#
#           FundCategory           FundType FundAccessPoint SBICFund  \
# 67050  Venture Capital  Venture - General    Primary Fund       No
#
#         CloseDate    OpenDate  FundTargetSizeLow  FundTargetSizeHigh  \
# 67050  01/01/2013  11/01/2012               50.0                 NaN
#
#       FundTargetSize                Domiciles    FundLocation    FundCity  \
# ...

# %%
fund_ids_dict[12] = list(df_12[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F']}

# %%
fund_investors_dict[12] = inv_12
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund']}

# %%
fund_ids_dict[13] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: []}

# %%
fund_investors_dict[13] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: []}

# %%
fund_ids_dict[14] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: []}

# %%
fund_investors_dict[14] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: []}

# %%
inv_15 = ["Orlando Health"]
msk = df_funds[var.investor].eq(inv_15[0])
df_15 = df_funds[msk]
df_15
# Out:
#           FundID                    FundName FundFormerName FundNo  \
# 4524   22073-86F  Orlando Health Ventures II           None      2
# 27983  17324-11F   Orlando Health Ventures I           None      1
#
#                   FirstFund        Investor  \
# 4524                   None  Orlando Health
# 27983  Yes (Orlando Health)  Orlando Health
#
#                               InvestorWebsite  Vintage FundStatus  FundSize  \
# 4524   Orlando Health (www.orlandohealth.com)      NaN       Open    125.00
# 27983  Orlando Health (www.orlandohealth.com)      NaN     Closed     21.25
#
#        NativeFundSize NativeFundCurrency FundSizeGroup    FundCategory  \
# 4524           125.00                USD   100M - 249M  Private Equity
# 27983           21.25                USD       0 - 99M  Private Equity
#
#       FundType FundAccessPoint SBICFund CloseDate    OpenDate  \
# 4524    Buyout    Primary Fund       No      None  07/22/2022
# ...

# %%
fund_ids_dict[15] = list(df_15[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F']}

# %%
fund_investors_dict[15] = inv_15
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health']}

# %%
inv_16 = ["OSF Ventures"]
msk = df_funds[var.investor].eq(inv_16[0])
df_16 = df_funds[msk]
df_16
# Out:
#           FundID           FundName FundFormerName FundNo           FirstFund  \
# 21845  20618-65F   OSF Ventures III           None      3                None
# 50646  16701-67F    OSF Ventures II           None      2                None
# 58344  15958-81F  OSF Ventures Fund           None      1  Yes (OSF Ventures)
#
#            Investor                     InvestorWebsite  Vintage FundStatus  \
# 21845  OSF Ventures  OSF Ventures (www.osfventures.org)      NaN       Open
# 50646  OSF Ventures  OSF Ventures (www.osfventures.org)   2019.0     Closed
# 58344  OSF Ventures  OSF Ventures (www.osfventures.org)   2017.0     Closed
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 21845       NaN             NaN                USD          None
# 50646      75.0            75.0                USD       0 - 99M
# 58344       NaN             NaN                USD          None
#
#           FundCategory           FundType FundAccessPoint SBICFund  \
# ...

# %%
fund_ids_dict[16] = list(df_16[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F']}

# %%
fund_investors_dict[16] = inv_16
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures']}

# %%
inv_17 = ["Mass General Brigham Innovation", "Mass General Brigham Ventures"]
fund_ids_17 = ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F']
msk = df_funds[var.fund_id].isin(fund_ids_17)
df_17 = df_funds[msk]
df_17
# Out:
#           FundID                                           FundName  \
# 41711  18303-94F                      Mass General Brigham Fund III
# 52426  16855-39F  Artificial Intelligence and Digital Translatio...
# 52428  16855-48F                      Translational Innovation Fund
# 60157  15786-10F                        Partners Innovation Fund II
# 78019  13309-75F                           Partners Innovation Fund
#
#       FundFormerName                                             FundNo  \
# 41711           None                                                  3
# 52426           None  1 (Mass General Brigham), 3 (Mass General Brig...
# 52428           None  2 (Mass General Brigham), 4 (Mass General Brig...
# 60157           None  2 (Mass General Brigham Innovation), 2 (Mass G...
# 78019           None  1 (Mass General Brigham Innovation), 1 (Mass G...
#
#                                  FirstFund  \
# 41711                                 None
# ...

# %%
fund_ids_dict[17] = fund_ids_17
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F']}

# %%
fund_investors_dict[17] = inv_17
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures']}

# %%
inv_18 = ["Providence Ventures"]
msk = df_funds[var.investor].eq(inv_18[0])
df_18 = df_funds[msk]
df_18
# Out:
#           FundID                     FundName FundFormerName FundNo  \
# 41888  16054-75F     Providence Ventures Fund           None      1
# 48264  16527-61F  Providence Ventures Fund II           None      2
#
#                        FirstFund             Investor  \
# 41888  Yes (Providence Ventures)  Providence Ventures
# 48264                       None  Providence Ventures
#
#                                         InvestorWebsite  Vintage FundStatus  \
# 41888  Providence Ventures (www.providenceventures.org)   2014.0     Closed
# 48264  Providence Ventures (www.providenceventures.org)   2019.0     Closed
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 41888     150.0           150.0                USD   100M - 249M
# 48264     150.0           150.0                USD   100M - 249M
#
#           FundCategory           FundType FundAccessPoint SBICFund  \
# 41888  Venture Capital  Venture - General    Primary Fund       No
# ...

# %%
fund_ids_dict[18] = list(df_18[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F'],
#  18: ['16054-75F', '16527-61F']}

# %%
fund_investors_dict[18] = inv_18
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures'],
#  18: ['Providence Ventures']}

# %%
inv_19 = ["Texas Medical Center"]
msk = df_funds[var.investor].eq(inv_19[0])
df_19 = df_funds[msk]
df_19
# Out:
#           FundID          FundName FundFormerName FundNo  \
# 42944  16134-04F  TMC Venture Fund           None      1
#
#                         FirstFund              Investor  \
# 42944  Yes (Texas Medical Center)  Texas Medical Center
#
#                           InvestorWebsite  Vintage FundStatus  FundSize  \
# 42944  Texas Medical Center (www.tmc.edu)   2017.0     Closed      25.0
#
#        NativeFundSize NativeFundCurrency FundSizeGroup     FundCategory  \
# 42944            25.0                USD       0 - 99M  Venture Capital
#
#                             FundType FundAccessPoint SBICFund   CloseDate  \
# 42944  Venture Capital - Early Stage    Primary Fund       No  11/08/2017
#
#       OpenDate  FundTargetSizeLow  FundTargetSizeHigh FundTargetSize  \
# 42944     None                NaN                 NaN           None
#
#            Domiciles FundLocation FundCity FundState_Province    FundCountry  \
# ...

# %%
fund_ids_dict[19] = list(df_19[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F'],
#  18: ['16054-75F', '16527-61F'],
#  19: ['16134-04F']}

# %%
fund_investors_dict[19] = inv_19
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures'],
#  18: ['Providence Ventures'],
#  19: ['Texas Medical Center']}

# %%
fund_ids_dict[20] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F'],
#  18: ['16054-75F', '16527-61F'],
#  19: ['16134-04F'],
#  20: []}

# %%
fund_investors_dict[20] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures'],
#  18: ['Providence Ventures'],
#  19: ['Texas Medical Center'],
#  20: []}

# %%
inv_21 = ["UnityPoint Health"]
msk = df_funds[var.investor].eq(inv_21[0])
df_21 = df_funds[msk]
df_21
# Out:
#           FundID                                    FundName FundFormerName  \
# 56020  16624-63F  UnityPoint Health Ventures Innovation Fund           None
#
#       FundNo                FirstFund           Investor  \
# 56020      1  Yes (UnityPoint Health)  UnityPoint Health
#
#                               InvestorWebsite  Vintage FundStatus  FundSize  \
# 56020  UnityPoint Health (www.unitypoint.org)   2020.0     Closed       NaN
#
#        NativeFundSize NativeFundCurrency FundSizeGroup     FundCategory  \
# 56020             NaN                USD          None  Venture Capital
#
#                             FundType FundAccessPoint SBICFund   CloseDate  \
# 56020  Venture Capital - Early Stage    Primary Fund       No  12/31/2020
#
#          OpenDate  FundTargetSizeLow  FundTargetSizeHigh FundTargetSize  \
# 56020  05/23/2019              100.0                 NaN          > 100
#
#                  Domiciles         FundLocation         FundCity  \
# ...

# %%
fund_ids_dict[21] = list(df_21[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F'],
#  18: ['16054-75F', '16527-61F'],
#  19: ['16134-04F'],
#  20: [],
#  21: ['16624-63F']}

# %%
fund_investors_dict[21] = inv_21
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures'],
#  18: ['Providence Ventures'],
#  19: ['Texas Medical Center'],
#  20: [],
#  21: ['UnityPoint Health']}

# %%
inv_22 = ["University Hospitals Ventures"]
msk = df_funds[var.investor].eq(inv_22[0])
df_22 = df_funds[msk]
df_22
# Out:
#           FundID                         FundName FundFormerName FundNo  \
# 7028   22402-36F    Healthcare Collaboration Fund           None      2
# 16048  22402-18F  UH Ventures (off-Balance sheet)           None      1
#
#       FirstFund                       Investor  \
# 7028       None  University Hospitals Ventures
# 16048      None  University Hospitals Ventures
#
#                                          InvestorWebsite  Vintage FundStatus  \
# 7028   University Hospitals Ventures (ventures.uhhosp...   2021.0     Closed
# 16048  University Hospitals Ventures (ventures.uhhosp...      NaN  Evergreen
#
#        FundSize  NativeFundSize NativeFundCurrency FundSizeGroup  \
# 7028        8.0             8.0                USD       0 - 99M
# 16048       NaN             NaN                USD          None
#
#           FundCategory                       FundType FundAccessPoint  \
# 7028   Venture Capital  Venture Capital - Early Stage    Primary Fund
# ...

# %%
fund_ids_dict[22] = list(df_22[var.fund_id])
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F'],
#  18: ['16054-75F', '16527-61F'],
#  19: ['16134-04F'],
#  20: [],
#  21: ['16624-63F'],
#  22: ['22402-36F', '22402-18F']}

# %%
fund_investors_dict[22] = inv_22
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures'],
#  18: ['Providence Ventures'],
#  19: ['Texas Medical Center'],
#  20: [],
#  21: ['UnityPoint Health'],
#  22: ['University Hospitals Ventures']}

# %%
fund_ids_dict[23] = []
fund_ids_dict
# Out:
# {1: ['11004-85F', '11715-58F', '13492-36F', '15744-88F', '17559-19F'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['17580-43F'],
#  7: [],
#  8: [],
#  9: ['16929-91F',
#   '13943-26F',
#   '13168-45F',
#   '11195-11F',
#   '11195-20F',
#   '11195-29F',
#   '11195-38F',
#   '11195-47F'],
#  10: ['15463-27F'],
#  11: ['16885-63F'],
#  12: ['13847-14F'],
#  13: [],
#  14: [],
#  15: ['22073-86F', '17324-11F'],
#  16: ['20618-65F', '16701-67F', '15958-81F'],
#  17: ['18303-94F', '16855-39F', '16855-48F', '15786-10F', '13309-75F'],
#  18: ['16054-75F', '16527-61F'],
#  19: ['16134-04F'],
#  20: [],
#  21: ['16624-63F'],
#  22: ['22402-36F', '22402-18F'],
#  23: []}

# %%
fund_investors_dict[23] = []
fund_investors_dict
# Out:
# {1: ['Ascension Ventures'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: ['Intermountain Ventures'],
#  7: [],
#  8: [],
#  9: ['Kaiser Permanente Ventures'],
#  10: ['Ochsner Lafayette General'],
#  11: ['Mayo Clinic Ventures'],
#  12: ['MemorialCare Innovation Fund'],
#  13: [],
#  14: [],
#  15: ['Orlando Health'],
#  16: ['OSF Ventures'],
#  17: ['Mass General Brigham Innovation', 'Mass General Brigham Ventures'],
#  18: ['Providence Ventures'],
#  19: ['Texas Medical Center'],
#  20: [],
#  21: ['UnityPoint Health'],
#  22: ['University Hospitals Ventures'],
#  23: []}

# %%
# Total number of funds
all_ids = []
for v in fund_ids_dict.values():
    all_ids += v
len(all_ids)
# Out:
# 33
