# %%
# Download pb data to server from Richard Tahkora Dropbox

# %%
# !wget "https://www.dropbox.com/scl/fi/wclm3d2wifautzpxf5606/Pitchbook-Full-Data.zip?rlkey=yv5ijm3fn5e87tfpamstwg2su&dl=0"
# Out:
# --2025-09-24 12:08:38--  https://www.dropbox.com/scl/fi/wclm3d2wifautzpxf5606/Pitchbook-Full-Data.zip?rlkey=yv5ijm3fn5e87tfpamstwg2su&dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc21aabffed1d1840baa556ed572.dl.dropboxusercontent.com/cd/0/inline/Cx8LWWUUG3HBI7-FNmJeOWSBIpZuXFBFZb8u0BVFcG77HCQfhO2kHP9dWy3NbCmBu31BTBbai4rrGUxvgKC_cm3rAvI-Tb9ARwRfT19-NjZOQGSA9cEMOrwvP-p2DEgxchMV8FRqva6nz9kxVKf6ar_I/file# [following]
# --2025-09-24 12:08:38--  https://uc21aabffed1d1840baa556ed572.dl.dropboxusercontent.com/cd/0/inline/Cx8LWWUUG3HBI7-FNmJeOWSBIpZuXFBFZb8u0BVFcG77HCQfhO2kHP9dWy3NbCmBu31BTBbai4rrGUxvgKC_cm3rAvI-Tb9ARwRfT19-NjZOQGSA9cEMOrwvP-p2DEgxchMV8FRqva6nz9kxVKf6ar_I/file
# ...

# %%
# rename
# !mv 'Pitchbook-Full-Data.zip?rlkey=yv5ijm3fn5e87tfpamstwg2su&dl=0' 'Pitchbook-Full-Data.zip'
# Out:
# mv: cannot stat 'Pitchbook-Full-Data.zip?rlkey=yv5ijm3fn5e87tfpamstwg2su&dl=0': No such file or directory

# %%
# !unzip "Pitchbook-Full-Data.zip"
# Out:
# Archive:  Pitchbook-Full-Data.zip
#   inflating: Company.csv
#   inflating: Deal.csv
# Deal.csv:  write error (disk full?).  Continue? (y/n/^C)
